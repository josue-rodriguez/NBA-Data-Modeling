# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.basketball-reference.com/leagues/NBA_2018_per_game.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")

# %%
pretty_soup = soup.prettify()
print(pretty_soup[0:20])

# %%
print(soup.title)
# Out:
# <title>2017-18 NBA Player Stats: Per Game | Basketball-Reference.com</title>

# %%
stat_names_info = soup.findAll('th')
stat_names = [info.get('data-stat') for info in stat_names_info[1:29]]

# there are 29 stats in the table
stat_names
# Out:
# ['player',
#  'pos',
#  'age',
#  'team_id',
#  'g',
#  'gs',
#  'mp_per_g',
#  'fg_per_g',
#  'fga_per_g',
#  'fg_pct',
#  'fg3_per_g',
#  'fg3a_per_g',
#  'fg3_pct',
#  'fg2_per_g',
#  'fg2a_per_g',
#  'fg2_pct',
#  'efg_pct',
#  'ft_per_g',
#  'fta_per_g',
#  'ft_pct',
#  'orb_per_g',
#  'drb_per_g',
#  'trb_per_g',
#  'ast_per_g',
#  'stl_per_g',
#  'blk_per_g',
#  'tov_per_g',
#  'pf_per_g']

# %%
# find all rows containing pertinent data
table_rows = soup.find_all('tr', class_ = 'full_table')

# %%
data = {}

for table_row in table_rows:
    
    # within each row, find all cells containing data e.g. 'td'
    row_cells = table_row.findAll('td')
    
    for cell in range(0, len(row_cells)):
        # define key and value(value needs to be in a list for this method to work)
        key = row_cells[cell].get('data-stat')
        value = [row_cells[cell].text.strip()]
        
        # for every row cell, get the stat name, and the corresponding value
        if key in data.keys():
            
            # if the key exists, update the values
            data[key] += value
            
        else:
            # else create the key and add value
            data[key] = value

# %%
df = pd.DataFrame(data)

# %%
print(df.shape)
# Out:
# (540, 29)

# %%
df.head(15)
# Out:
#    age ast_per_g blk_per_g drb_per_g efg_pct fg2_pct fg2_per_g fg2a_per_g  \
# 0   24       0.4       0.1       1.2    .540    .443       0.4        0.9
# 1   27       0.8       0.4       3.1    .496    .384       0.4        1.0
# 2   24       1.2       1.0       4.0    .629    .631       5.9        9.3
# 3   20       1.5       0.6       3.8    .512    .523       2.5        4.8
# 4   32       0.6       0.2       1.2    .485    .413       0.7        1.7
# 5   29       0.1       0.0       0.6    .333    .333       0.2        0.7
# 6   32       2.0       1.2       5.2    .520    .526       8.8       16.7
# 7   19       0.7       1.2       3.4    .596    .599       3.2        5.3
# 8   25       0.7       0.1       0.4    .273    .545       0.3        0.6
# 9   36       0.4       0.1       1.2    .505    .506       1.8        3.6
# 10  27       1.2       0.6       6.2    .503    .432       1.5        3.5
# 11  24       0.7       0.2       1.8    .515    .535       1.4        2.6
# 12  24       2.7       0.8       4.2    .549    .556       2.9        5.1
# 13  29       0.9       0.3       3.6    .568    .539       1.2        2.1
# 14  19       0.0       0.3       0.4    .444    .444       0.4        0.8
#
#    fg3_pct fg3_per_g    ...    mp_per_g orb_per_g pf_per_g             player  \
# 0     .380       1.1    ...        15.1       0.3      1.7       Alex Abrines
# 1     .349       1.5    ...        19.4       0.6      2.1         Quincy Acy
# 2     .000       0.0    ...        32.7       5.1      2.8       Steven Adams
# 3     .000       0.0    ...        19.8       1.7      2.0        Bam Adebayo
# 4     .386       0.5    ...        12.9       0.1      1.1      Arron Afflalo
# 5                0.0    ...         2.3       0.1      0.5       Cole Aldrich
# 6     .293       0.4    ...        33.5       3.3      2.2  LaMarcus Aldridge
# 7     .333       0.1    ...        20.0       2.0      2.0      Jarrett Allen
# 8     .000       0.0    ...         5.9       0.2      0.8       Kadeem Allen
# 9     .333       0.2    ...        12.4       0.9      2.2         Tony Allen
# 10    .369       1.8    ...        30.0       1.4      2.0    Al-Farouq Aminu
# 11    .330       0.9    ...        13.7       0.7      1.4    Justin Anderson
# 12    .333       0.3    ...        26.7       1.1      1.5      Kyle Anderson
# 13    .386       2.0    ...        26.1       1.4      1.9      Ryan Anderson
# 14               0.0    ...         2.7       0.5      0.1       Ike Anigbogu
#
#    pos pts_per_g stl_per_g team_id tov_per_g trb_per_g
# 0   SG       4.7       0.5     OKC       0.3       1.5
# 1   PF       5.9       0.5     BRK       0.9       3.7
# 2    C      13.9       1.2     OKC       1.7       9.0
# 3    C       6.9       0.5     MIA       1.0       5.5
# 4   SG       3.4       0.1     ORL       0.4       1.2
# 5    C       0.6       0.1     MIN       0.0       0.7
# 6    C      23.1       0.6     SAS       1.5       8.5
# 7    C       8.2       0.4     BRK       1.1       5.4
# 8   PG       1.1       0.2     BOS       0.5       0.6
# 9   SF       4.7       0.5     NOP       0.9       2.1
# 10  PF       9.3       1.1     POR       1.1       7.6
# 11  SF       6.2       0.4     PHI       0.4       2.4
# 12  SF       7.9       1.6     SAS       1.3       5.4
# 13  PF       9.3       0.4     HOU       0.6       5.0
# 14   C       1.2       0.1     IND       0.2       0.8
#
# [15 rows x 29 columns]

# %%
df.to_csv('~/Desktop/per_game_2018.csv')
